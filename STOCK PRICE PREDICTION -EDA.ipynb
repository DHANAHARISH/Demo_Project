# %% [markdown]
# ## STOCK PRICE PREDICTION -EDA
# ## Exploratory Data Analysis(EDA) :
#     .Exploratory Data Analysis (EDA) is an approach to analyze the data using visual techniques. It is used to discover          trends, patterns, or to check assumptions with the help of statistical summary and graphical representations.
# ## stock Discreption
#     1.Date The date of each trading day within the specified time frame.
#     2.Open:The opening price of Netflix stock on each trading day.
#     3.High:The highest price reached by Netflix stock during the trading day.
#     4.Low: The lowest price reached by Netflix stock during the trading day.
#     5.Close: The closing price of Netflix stock on each trading day.
#     6.Adj Close: The adjusted closing price of Netflix stock on each trading day. The adjusted closing price accounts for         any corporate actions, such as stock splits or dividends, that occurred during the trading period, providing a more         accurate representation of the stock's value.
#     7.Volume: The trading volume of Netflix stock on each trading day, representing the total number of shares traded.

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read data
#       Assuming the "Netflix Stock Price Prediction Dataset" is in CSV format, here's how the data might be represented:

# %%
df=pd.read_csv("D:/DS NOTE/PROJECT/Netflix data.csv")
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 0     11896100
# ...

# %% [markdown]
# # Data Preprocessing

# %%
# Print a concise summary of a DataFrame.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   object
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB

# %% [markdown]
#     *In this dataframe  date column ,we cannot encode this Categorical to numerical  the colum date is in object datatype        format , so we have to change  datetime concept as int

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 1004  20047500
# 1005  22542300
# 1006  14346000
# 1007   9905200
# 1008   7782400

# %%
# Convert argument to datetime
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1    2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2    2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3    2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4    2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...         ...         ...         ...         ...         ...         ...
# 1004 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 0     11896100
# 1     12595800
# ...

# %%
#Count number of distinct elements in specified axis.
df.nunique()
# Out:
# Date         1009
# Open          976
# High          983
# Low           989
# Close         988
# Adj Close     988
# Volume       1005
# dtype: int64

# %%
# Detect missing values.there is no null value 
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Return boolean Series denoting duplicate rows.there is no duplicate in dataframe 
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
#     .Duplicates  - Repated entry / contain same value or record
#      .Why we have to remove -.same data records can be seen in both train and test dataset result in data leakage                    .so we have to remove the duplicate

# %%
#Return a tuple representing the dimensionality of the DataFrame.
df.shape
# Out:
# (1009, 7)

# %% [markdown]
# # Visualization of Netflix Stock

# %%
# Outliers 
plt.figure(figsize=(8 ,5))
sns.boxplot(df,orient='h')
plt.title('Entire data outliers')
plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
# whole data plot to  find # Outliers 



plt.figure(figsize=(8 ,5))
sns.boxplot(df['Open'],orient='h')
plt.title('open ')


plt.figure(figsize=(8 ,5))
sns.boxplot(df['High'],orient='h')
plt.title('High')


plt.figure(figsize=(8 ,5))
sns.boxplot(df['Low'],orient='h')
plt.title('low')


plt.figure(figsize=(8 ,5))
sns.boxplot(df['Close'],orient='h')
plt.title('close')


plt.figure(figsize=(8 ,5))
sns.boxplot(df['Adj Close'],orient='h')
plt.title('Adj close')


plt.figure(figsize=(8 ,5))
sns.boxplot(df['Volume'],orient='h')
plt.title('volume')

plt.show()

# %% [markdown]
# # Outlier remove

# %%
q1=df['Volume'].quantile(0.25)
q3=df['Volume'].quantile(0.75)
IQR=q3-q1
lower_range=q1-1.5*IQR
upper_range=q3+IQR 

print(f"q1 = {q1}\nq3 = {q3}\nIQR = {IQR}\nlower_range = {lower_range}\nupper_range = {upper_range}")
# Out:
# q1 = 4091900.0
# q3 = 9322400.0
# IQR = 5230500.0
# lower_range = -3753850.0
# upper_range = 14552900.0

# %%
df['Volume']=np.where(df['Volume']<lower_range,lower_range,
                      np.where(df['Volume']>upper_range,upper_range,
                      df['Volume']))
df['Volume']
# Out:
# 0       11896100.0
# 1       12595800.0
# 2        8981500.0
# 3        9306700.0
# 4       14552900.0
#            ...
# 1004    14552900.0
# 1005    14552900.0
# 1006    14346000.0
# 1007     9905200.0
# 1008     7782400.0
# Name: Volume, Length: 1009, dtype: float64

# %%
plt.figure(figsize=(8 ,5))
sns.boxplot(df['Volume'],orient='h')
plt.title('outlier romoved volume plot ')
# Out:
# Text(0.5, 1.0, 'outlier romoved volume plot ')

# %%
df['Year'] =df['Date'].dt.year
df['Month'] =df['Date'].dt.month
df['Day'] = df['Date'].dt.day
X=df.drop(['Date','Close','Adj Close'],axis=1).copy()
Y =df['Close'].copy()

# %%
X
# Out:
#             Open        High         Low      Volume  Year  Month  Day
# 0     262.000000  267.899994  250.029999  11896100.0  2018      2    5
# 1     247.699997  266.700012  245.000000  12595800.0  2018      2    6
# 2     266.579987  272.450012  264.329987   8981500.0  2018      2    7
# 3     267.079987  267.619995  250.000000   9306700.0  2018      2    8
# 4     253.850006  255.800003  236.110001  14552900.0  2018      2    9
# ...          ...         ...         ...         ...   ...    ...  ...
# 1004  401.970001  427.700012  398.200012  14552900.0  2022      1   31
# 1005  432.959991  458.480011  425.540009  14552900.0  2022      2    1
# 1006  448.250000  451.980011  426.480011  14346000.0  2022      2    2
# 1007  421.440002  429.260010  404.279999   9905200.0  2022      2    3
# 1008  407.309998  412.769989  396.640015   7782400.0  2022      2    4
#
# [1009 rows x 7 columns]

# %%
Y
# Out:
# 0       254.259995
# 1       265.720001
# 2       264.559998
# 3       250.100006
# 4       249.470001
#            ...
# 1004    427.140015
# 1005    457.130005
# 1006    429.480011
# 1007    405.600006
# 1008    410.170013
# Name: Close, Length: 1009, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=345)

# %% [markdown]
# # Model plottree and elbow plot

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.tree import plot_tree
rf=RandomForestRegressor()
rf.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
# estimators_ is DecisionTreeRegressor make tree plot in random forest 
rf.estimators_
# Out:
# [DecisionTreeRegressor(max_features=1.0, random_state=1114199461),
#  DecisionTreeRegressor(max_features=1.0, random_state=954710526),
#  DecisionTreeRegressor(max_features=1.0, random_state=1508392201),
#  DecisionTreeRegressor(max_features=1.0, random_state=926702426),
#  DecisionTreeRegressor(max_features=1.0, random_state=1800335887),
#  DecisionTreeRegressor(max_features=1.0, random_state=1283928395),
#  DecisionTreeRegressor(max_features=1.0, random_state=1816938741),
#  DecisionTreeRegressor(max_features=1.0, random_state=695984407),
#  DecisionTreeRegressor(max_features=1.0, random_state=808542840),
#  DecisionTreeRegressor(max_features=1.0, random_state=1538223174),
#  DecisionTreeRegressor(max_features=1.0, random_state=1119123960),
#  DecisionTreeRegressor(max_features=1.0, random_state=1999544712),
#  DecisionTreeRegressor(max_features=1.0, random_state=883080596),
#  DecisionTreeRegressor(max_features=1.0, random_state=1065079562),
# ...

# %%
plt.figure(figsize=(20,20))
plot_tree(rf.estimators_[0],max_depth=5,filled=True,fontsize=(15),feature_names=X.columns)
plt.show()

# %%
# feature_importances_
plt.barh(X.columns,rf.feature_importances_)
# Out:
# <BarContainer object of 7 artists>

# %%
y_pred=rf.predict(X_test)
print('MSE:',mean_squared_error(Y_test,y_pred))
print('Train score ',rf.score(X_train,Y_train)*100)
print('Test score ',rf.score(X_test,Y_test)*100)
# Out:
# MSE: 29.998555310834767
# Train score  99.96615239729921
# Test score  99.73707938621314

# %%
def rf_function(k):
    rf=RandomForestRegressor(n_estimators=k)
    rf.fit(X_train,Y_train)
    y_pred=rf.predict(X_test)
    mse=mean_squared_error(Y_test,y_pred)
    return mse

# %%
rf_function(4)
# Out:
# 36.66441406871231

# %%
k_value=range(1,21)
mse=[]
for k in k_value:
    error=rf_function(k)
    mse.append(error)

# %%
mse
# Out:
# [58.78103780692733,
#  49.92603243790815,
#  33.707318496708396,
#  34.0608172147726,
#  34.91273699232945,
#  31.18443807815354,
#  31.860692648636615,
#  34.76459601378293,
#  32.00775818321283,
#  29.791574268472043,
#  32.73634377234194,
#  31.94625883895684,
#  38.37033686514682,
#  32.43575537746708,
#  30.036311557764467,
#  34.02023089902497,
#  31.656823901544808,
#  31.098132498695453,
#  30.638121039514097,
#  30.69714503364196]

# %%
plt.plot(k_value,mse,marker='o')
plt.xlabel('k')
plt.ylabel('error')
plt.title('rf elbow method')
plt.show()

# %%
X.columns
# Out:
# Index(['Open', 'High', 'Low', 'Volume', 'Year', 'Month', 'Day'], dtype='object')

# %%
# Create the clustermap
plt.figure(figsize=(10, 8))
sns.clustermap(df['Volume'].values.reshape(-1, 1), cmap='viridis', col_cluster=False)
plt.title('Netflix Stock Volume Clustermap')
plt.xlabel('Volume')
plt.ylabel('Samples')
plt.show()

# %% [markdown]
#     .The clustermap function in the seaborn library is used to create a clustered heatmap, which helps visualize the            patterns in the data by clustering rows and columns based on similarity. The function is especially useful for              exploring correlations and patterns in large datasets.

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(X.corr(),annot=True,cmap='Blues')
plt.show()

# %%
# Plot pairwise relationships in a dataset.
plt.figure(figsize=(10, 8))
sns.pairplot(df)
plt.show()

# %%
df.plot.hist(alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
#     A histogram is a representation of the distribution of data.
#     This function groups the values of all given Series in the DataFrame

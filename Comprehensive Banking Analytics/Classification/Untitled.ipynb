# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.experimental import enable_hist_gradient_boosting 
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
df=pd.read_csv("D:/DS NOTE/My external project/IndustrialCopperModeling/Copper_Set.xlsx - Result 1.csv")
df
# Out:
#                                           id   item_date quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262
# ...                                      ...         ...           ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76  20200702.0   102.4824216
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB  20200702.0   208.0864686
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320  20200702.0   4.235593568
# 181671  7AFFD323-01D9-4E15-B80D-7D1B03498FC8  20200702.0         -2000
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC  20200702.0   406.6865384
#
#           customer  country status item type  application  thickness   width  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181673 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             181671 non-null  object
#  1   item_date      181672 non-null  float64
#  2   quantity tons  181673 non-null  object
#  3   customer       181672 non-null  float64
#  4   country        181645 non-null  float64
#  5   status         181671 non-null  object
#  6   item type      181673 non-null  object
#  7   application    181649 non-null  float64
#  8   thickness      181672 non-null  float64
#  9   width          181673 non-null  float64
#  10  material_ref   103754 non-null  object
#  11  product_ref    181673 non-null  int64
#  12  delivery date  181672 non-null  float64
#  13  selling_price  181672 non-null  float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 19.4+ MB

# %%
df.head()
# Out:
#                                      id   item_date quantity tons    customer  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139  30156308.0
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839  30202938.0
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949  30153963.0
# 3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065  30349574.0
# 4  4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262  30211560.0
#
#    country status item type  application  thickness   width  \
# 0     28.0    Won         W         10.0       2.00  1500.0
# 1     25.0    Won         W         41.0       0.80  1210.0
# 2     30.0    Won        WI         28.0       0.38   952.0
# 3     32.0    Won         S         59.0       2.30  1317.0
# 4     28.0    Won         W         10.0       4.00  2000.0
#
#                                material_ref  product_ref  delivery date  \
# ...

# %% [markdown]
# # Convert argument to a numeric type

# %%
# Convert 'quantity tons' to float64 type, replacing non-numeric values with NaN
df['quantity tons'] = pd.to_numeric(df['quantity tons'], errors='coerce').astype('float64')

# %%
# Replace values starting with '00000' with NaN
df['material_ref'] = np.where(df['material_ref'].str.startswith('00000'), np.nan, df['material_ref'])

# %%
df['item_date']=pd.to_datetime(df['item_date'])
df['delivery date']=pd.to_datetime(df['delivery date'])

# %%
df['Day']=df['item_date'].dt.day
df['deliveryDay']=df['delivery date'].dt.day

df['Month']=df['delivery date'].dt.month
df['deliveryMonth']=df['delivery date'].dt.month

df['Year']=df['delivery date'].dt.year
df['deliveryYear']=df['delivery date'].dt.year

# %%
# Identify types of variables
categorical_columns = ['customer', 'country', 'status', 'item type', 'material_ref']
continuous_columns = ['quantity tons', 'application', 'thickness', 'width', 'product_ref', 'selling_price']

# %%
# Handle missing values with median for continuous variables and mode for categorical variables
df[continuous_columns] = df[continuous_columns].fillna(df[continuous_columns].median())
df[categorical_columns] = df[categorical_columns].fillna(df[categorical_columns].mode().iloc[0])

# %%
# Treat Outliers using Isolation Forest
iso_forest = IsolationForest(contamination=0.05, random_state=42)
df['outlier'] = iso_forest.fit_predict(df.select_dtypes(include=np.number))
df1 = df[df['outlier'] == 1].drop(columns=['outlier'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Treat Outliers using Isolation Forest
# ----> 2 iso_forest = IsolationForest(contamination=0.05, random_state=42)
#       3 df['outlier'] = iso_forest.fit_predict(df.select_dtypes(include=np.number))
#       4 df1 = df[df['outlier'] == 1].drop(columns=['outlier'])
#
# NameError: name 'IsolationForest' is not defined

# %%
outliers_mask
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 181668    False
# 181669     True
# 181670    False
# 181671     True
# 181672     True
# Length: 181673, dtype: bool

# %%
df1.boxplot(figsize=(10,10))
plt.tight_layout()
plt.show()

# %% [raw]
# # Step 1: Data Understanding
# import pandas as pd
#
# # Load the data
# df = pd.read_csv('your_data.csv')
#
# # Identify types of variables
# categorical_columns = ['customer', 'country', 'status', 'item type', 'material_ref']
# continuous_columns = ['quantity tons', 'application', 'thickness', 'width', 'product_ref', 'selling_price']
#
# # Convert rubbish values in 'material_ref' starting with '00000' to null
# df['material_ref'] = df['material_ref'].replace({'00000.*': None}, regex=True)
#
# # Drop 'id' and 'item_date' columns as they may not be useful
# df = df.drop(['id', 'item_date'], axis=1)
#
# # Step 2: Data Preprocessing
# # Handle missing values with median for continuous variables and mode for categorical variables
# df[continuous_columns] = df[continuous_columns].fillna(df[continuous_columns].median())
# df[categorical_columns] = df[categorical_columns].fillna(df[categorical_columns].mode().iloc[0])
#
# # Treat outliers using IQR for continuous variables
# Q1 = df[continuous_columns].quantile(0.25)
# Q3 = df[continuous_columns].quantile(0.75)
# IQR = Q3 - Q1
# outliers_mask = ((df[continuous_columns] < (Q1 - 1.5 * IQR)) | (df[continuous_columns] > (Q3 + 1.5 * IQR))).any(axis=1)
# df = df[~outliers_mask]
#
# # Step 3: EDA
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Visualize outliers and skewness before treatment
# for column in continuous_columns:
#     plt.figure(figsize=(10, 6))
#     sns.boxplot(x=df[column])
#     plt.title(f'Boxplot for {column}')
#     plt.show()
#
# # Identify skewness and treat with log transformation for positively skewed variables
# skewness = df[continuous_columns].apply(lambda x: x.skew())
# skewness = skewness[abs(skewness) > 0.5]
# skewed_columns = skewness.index
# df[skewed_columns] = np.log
